# %% [markdown]
# # load packages

# %%
import warnings
warnings.filterwarnings("ignore")
import logging
logging.basicConfig(level=logging.WARNING)
import os
import random
import importlib
importlib.invalidate_caches()
import tensorflow as tf
tf.compat.v1.reset_default_graph()
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    tf.config.set_visible_devices(gpus[0], 'GPU')
    tf.config.experimental.set_memory_growth(gpus[0], True)
import anndata as ad
import pandas as pd
import numpy as np
import scanpy as sc
from scipy.sparse import csr_matrix
from scipy.spatial import distance
from matplotlib.patches import Wedge
from matplotlib.collections import PatchCollection
from matplotlib import colors as mcolors
import matplotlib.pyplot as plt
from AddaGCN import AddaGCN_API

def visualize_pie(proportion, spatial_location, colors=None, radius=None, seed=None):
    # Convert inputs to DataFrames
    res_results = pd.DataFrame(proportion)
    res_results = res_results.reindex(sorted(res_results.columns), axis=1)  # Equivalent to mixedsort
    
    location = pd.DataFrame(spatial_location)
    
    # Check if row names match
    if not res_results.index.equals(location.index):
        raise ValueError("The rownames of proportion data does not match with the rownames of spatial location data")
    
    # Define color candidates (same as in R code)
    colorCandidate = [
        "#1e77b4", "#ff7d0b", "#ceaaa3", "#2c9f2c", "#babc22", "#d52828", "#9267bc",
        "#8b544c", "#e277c1", "#d42728", "#adc6e8", "#97df89", "#fe9795", "#4381bd",
        "#f2941f", "#5aa43a", "#cc4d2e", "#9f83c8", "#91675a", "#da8ec8", "#929292",
        "#c3c237", "#b4e0ea", "#bacceb", "#f7c685", "#dcf0d0", "#f4a99f", "#c8bad8",
        "#F56867", "#FEB915", "#C798EE", "#59BE86", "#7495D3", "#D1D1D1", "#6D1A9C",
        "#15821E", "#3A84E6", "#997273", "#787878", "#DB4C6C", "#9E7A7A", "#554236",
        "#AF5F3C", "#93796C", "#F9BD3F", "#DAB370", "#877F6C", "#268785", "#f4f1de",
        "#e07a5f", "#3d405b", "#81b29a", "#f2cc8f", "#a8dadc", "#f1faee", "#f08080"
    ]
    
    # Handle colors
    if colors is None:
        if len(res_results.columns) > len(colorCandidate):
            # Create a color palette if needed
            cmap = plt.cm.get_cmap('Spectral')
            colors = [mcolors.rgb2hex(cmap(i)) for i in np.linspace(0, 1, len(res_results.columns))]
        else:
            if seed is not None:
                random.seed(seed)
            colors = random.sample(colorCandidate, len(res_results.columns))
    else:
        colors = colors
    
    # Combine data
    data = pd.concat([res_results, location], axis=1)
    ct_select = res_results.columns.tolist()
    
    # Calculate radius if not provided
    if radius is None:
        x_range = data['x'].max() - data['x'].min()
        y_range = data['y'].max() - data['y'].min()
        area = x_range * y_range
        radius = np.sqrt((area / len(data)) / np.pi) * 0.7
    else:
        radius = radius
    
    # Create figure
    fig, ax = plt.subplots(figsize=(10, 8))
    
    # Create pie charts for each point
    for idx, row in data.iterrows():
        x, y = row['x'], row['y']
        proportions = row[ct_select].values
        proportions = proportions / proportions.sum()  # Normalize
        
        # Calculate cumulative sums for wedge angles
        cumsum = np.cumsum(proportions)
        cumsum = np.insert(cumsum, 0, 0)
        
        # Create wedges
        wedges = []
        for i in range(len(proportions)):
            theta1 = cumsum[i] * 360
            theta2 = cumsum[i+1] * 360
            wedge = Wedge((x, y), radius, theta1, theta2, facecolor=colors[i])
            wedges.append(wedge)
        
        # Add wedges to plot
        pc = PatchCollection(wedges, match_original=True, edgecolor='none')
        ax.add_collection(pc)
    
    # Set aspect ratio
    ax.set_aspect('equal')
    
    # Set plot limits
    x_margin = (data['x'].max() - data['x'].min()) * 0.1
    y_margin = (data['y'].max() - data['y'].min()) * 0.1
    ax.set_xlim(data['x'].min() - x_margin, data['x'].max() + x_margin)
    ax.set_ylim(data['y'].min() - y_margin, data['y'].max() + y_margin)
    
    # Customize plot appearance
    ax.set_xticks([])
    ax.set_yticks([])
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    
    # Create legend
    legend_patches = [plt.Rectangle((0,0), 1, 1, fc=color) for color in colors]
    ax.legend(legend_patches, ct_select, title='Cell Type', 
              bbox_to_anchor=(1.05, 1), loc='upper left', 
              borderaxespad=0., frameon=False)
    
    plt.tight_layout()
    return fig, ax
# Out:
# 2025-04-14 21:52:38.058828: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2025-04-14 21:52:38.064846: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:16:00.0 name: NVIDIA GeForce RTX 4090 computeCapability: 8.9
# coreClock: 2.52GHz coreCount: 128 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 938.86GiB/s
# 2025-04-14 21:52:38.064975: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 1 with properties:
# pciBusID: 0000:34:00.0 name: NVIDIA GeForce RTX 4090 computeCapability: 8.9
# coreClock: 2.52GHz coreCount: 128 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 938.86GiB/s
# 2025-04-14 21:52:38.065089: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 2 with properties:
# pciBusID: 0000:ac:00.0 name: NVIDIA GeForce RTX 4090 computeCapability: 8.9
# coreClock: 2.52GHz coreCount: 128 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 938.86GiB/s
# 2025-04-14 21:52:38.065201: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 3 with properties:
# pciBusID: 0000:ca:00.0 name: NVIDIA GeForce RTX 4090 computeCapability: 8.9
# coreClock: 2.52GHz coreCount: 128 deviceMemorySize: 23.64GiB deviceMemoryBandwidth: 938.86GiB/s
# 2025-04-14 21:52:38.065338: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2025-04-14 21:52:38.066560: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2025-04-14 21:52:38.082236: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2025-04-14 21:52:38.082464: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2025-04-14 21:52:38.083755: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2025-04-14 21:52:38.084365: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2025-04-14 21:52:38.086976: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2025-04-14 21:52:38.087942: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0, 1, 2, 3

# %% [markdown]
# # load Data
# This tutorial demonstrates AddaGCN's ablility to accurate and robust decomposition of cell-type compositions in PDAC-B slice.
#
# In this tutorial, the PDAC-B slice and single-cell data were acquired from https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE111672.

# %%
input_dir = os.path.join('../AddaGCN')
os.chdir(input_dir)

# sp data
adata_sp = sc.read_h5ad("data/PDAC/adata_sp.h5ad")
adata_sp.var_names_make_unique()

# sc data
adata_sc = sc.read_h5ad("data/PDAC/adata_sc.h5ad")
adata_sc.var_names_make_unique()

inter_gene = list(set(adata_sp.var_names)&set(adata_sc.var_names))
adata_sp = adata_sp[:,inter_gene]
adata_sc = adata_sc[:,inter_gene]

# %% [markdown]
# # train model

# %%
AddaGCN = AddaGCN_API(adata_sp, adata_sc, num_markers=20, n_samples=1500,  nmix=8, sample_iter = 2,  ct_unm_fix = 2,
                      celltype = 'cellType', sp= 'spatial')
AddaGCN.Train_(loss_weight = [0.1, 1], epochs=1000, lr=[0.001,0.001],  initial_train_epochs=10, emb_dim=64,
               initial_train = True,enable_dann = True)
# Out:
# ... marker gene ...
# 4391608 (1733, 19736)
# 3894051.2 (1733, 19736)
# 1983494.2 (1733, 19736)
# -162412.38 (1733, 19736)
# ... pseudo ...
# ... Pseudo number ...
# Fixed number : 1118
# Unfixed number : 382
# 50003 (224, 230)
# 29456.0 (224, 230)
# 12547.0625 (224, 230)
# -62.10917 (224, 230)
# 1273964.4599124212 (1500, 230)
# 657562.4999999998 (1500, 230)
# 185398.6999901266 (1500, 230)
# -4.135358722123783e-12 (1500, 230)
# ... Graph ...
# ------Calculating spatial graph...
# ... Calculating A matrix ...
# <class 'numpy.matrix'> <class 'scipy.sparse._csr.csr_matrix'> <class 'numpy.ndarray'>
# 2025-04-14 21:52:48.073168: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2025-04-14 21:52:48.088453: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 1896000000 Hz
# 2025-04-14 21:52:48.095670: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f4cd0000b70 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2025-04-14 21:52:48.095695: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2025-04-14 21:52:48.169600: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x444e1f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-04-14 21:52:48.169666: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-04-14 21:52:48.170579: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:16:00.0 name: NVIDIA GeForce RTX 4090 computeCapability: 8.9
# coreClock: 2.52GHz coreCount: 128 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 938.86GiB/s
# 2025-04-14 21:52:48.170660: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2025-04-14 21:52:48.170691: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2025-04-14 21:52:48.170718: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2025-04-14 21:52:48.170743: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2025-04-14 21:52:48.170769: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2025-04-14 21:52:48.170793: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2025-04-14 21:52:48.170820: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2025-04-14 21:52:48.171537: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2025-04-14 21:52:48.171598: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2025-04-14 21:52:48.173070: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-04-14 21:52:48.173086: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2025-04-14 21:52:48.173098: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2025-04-14 21:52:48.173925: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 19889 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:16:00.0, compute capability: 8.9)
# 2025-04-14 21:52:49.196435: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# initial_train_done
# Epoch: 0000 train_loss= 2.5256 train_acc= 0.4469 val_loss= 2.5243 val_acc= 0.4815 test_loss= 2.5297 test_acc= 0.4667 time= 0.4585
# Epoch: 0200 train_loss= 2.0775 train_acc= 0.7111 val_loss= 2.0863 val_acc= 0.7185 test_loss= 2.1087 test_acc= 0.7133 time= 0.1752
# Epoch: 0400 train_loss= 2.0539 train_acc= 0.7325 val_loss= 2.0955 val_acc= 0.7407 test_loss= 2.1098 test_acc= 0.7533 time= 0.1739
# Epoch: 0600 train_loss= 2.0226 train_acc= 0.7481 val_loss= 2.0663 val_acc= 0.7630 test_loss= 2.0760 test_acc= 0.7667 time= 0.1901
# Epoch: 0800 train_loss= 1.9785 train_acc= 0.7753 val_loss= 2.0109 val_acc= 0.8000 test_loss= 2.0312 test_acc= 0.7667 time= 0.1545

# %% [markdown]
# # point plot

# %%
label = ['Cancer_clone_A', 'Ductal_terminal_ductal_like', 'Ductal_MHC_Class_II', 'Ductal_CRISP3_high-centroacinar_like', 'Endothelial_cells']
pred_real = AddaGCN.adata_sp.obs[label]
spot_x = np.array(AddaGCN.adata_sp.obsm['spatial'][:, 0])
spot_y = np.array(AddaGCN.adata_sp.obsm['spatial'][:, 1])
a = 2
b = 4
fig, axs = plt.subplots(a, b, figsize=(13, 5))
num_labels = len(label)
for i in range(a):
    for j in range(b):
        index = i * b + j
        if index < num_labels:
            cell1 = np.array(pred_real[label[i * b + j]])
            a_ = axs[i, j].scatter(spot_x, spot_y, s=25, cmap='PuRd', c=cell1)  
            fig.colorbar(a_, ax=axs[i, j])
            axs[i, j].set_title(label[i * b + j])
        else:
            axs[i, j].axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# # pie plot

# %%
adata_pseudo = AddaGCN.adata_pseudo.copy()
adata_sp = AddaGCN.adata_sp.copy()
label = list(adata_pseudo.obsm['pred_label'].columns)
pred_real = adata_sp.obs[label]

location = pd.DataFrame(AddaGCN.adata_sp.obsm['spatial'])
pred_real.index = location.index
location.columns = ['x', 'y']

# %%
coler_len = len(pred_real.columns)
colors = ["#FFD92F","#4DAF4A","#FCCDE5","#D9D9D9","#377EB8","#7FC97F","#BEAED4","#FDC086","#FFFF99","#386CB0","#F0027F",
           "#BF5B17","#666666","#1B9E77","#D95F02","#7570B3","#E7298A","#66A61E","#E6AB02","#A6761D","#9E0142","#D53E4F"]
fig, ax = visualize_pie(pred_real, location, colors[:coler_len])
plt.show()
